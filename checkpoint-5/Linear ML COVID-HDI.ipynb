# %%
paises = spark.read.format("csv").option("header", "true").load("dbfs:/FileStore/shared_uploads/frodriguez@insulet.com/pai_ses-2.csv")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
from pyspark.sql.functions import col

paises = paises.withColumn("total_cases_per_million", col("total_cases_per_million").cast("double"))
paises = paises.withColumn("total_deaths_per_million", col("total_deaths_per_million").cast("double"))
paises = paises.withColumn("diabetes_prevalence", col("diabetes_prevalence").cast("double"))
paises = paises.withColumn("hdi", col("hdi").cast("double"))
# casting strings for doubles

paises
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[2]: DataFrame[code: string, continent: string, country: string, date: string, total_cases_per_million: double, total_deaths_per_million: double, population_density: string, cardiovasc_death_rate: string, diabetes_prevalence: double, life_expectancy: string, hdi: double]</div>

# %%
paises = paises.na.drop()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## Train/Test Split
#
# ![](https://files.training.databricks.com/images/301/TrainTestSplit.png)
#
# **Question**: Why is it necessary to set a seed? What happens if I change my cluster configuration?

# %%
trainDF, testDF = paises.randomSplit([.8, .2], seed=42)
print(trainDF.cache().count())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">147
# </div>

# %% [markdown]
# Let's change the # of partitions (to simulate a different cluster configuration), and see if we get the same number of data points in our training set.

# %%
trainRepartitionDF, testRepartitionDF = (paises
                                         .repartition(24)
                                         .randomSplit([.8, .2], seed=42))

print(trainRepartitionDF.count())

# we just simulated a different cluster
# despite same seed 42, we have 158 rows instead of 165 (previous cell)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">146
# </div>

# %%
display(trainDF.select("total_cases_per_million", "hdi"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>total_cases_per_million</th><th>hdi</th></tr></thead><tbody><tr><td>3955.901</td><td>0.511</td></tr><tr><td>1925.701</td><td>0.581</td></tr><tr><td>249140.316</td><td>0.868</td></tr><tr><td>74322.974</td><td>0.89</td></tr><tr><td>117328.592</td><td>0.845</td></tr><tr><td>42044.81</td><td>0.778</td></tr><tr><td>134626.375</td><td>0.922</td></tr><tr><td>58789.766</td><td>0.756</td></tr><tr><td>1681.704</td><td>0.433</td></tr><tr><td>164586.66</td><td>0.931</td></tr><tr><td>759.824</td><td>0.452</td></tr><tr><td>9491.983</td><td>0.632</td></tr><tr><td>103146.235</td><td>0.816</td></tr><tr><td>158991.475</td><td>0.852</td></tr><tr><td>57591.821</td><td>0.814</td></tr><tr><td>70913.95</td><td>0.823</td></tr><tr><td>76537.051</td><td>0.716</td></tr><tr><td>46302.287</td><td>0.718</td></tr><tr><td>92333.199</td><td>0.814</td></tr><tr><td>34654.34</td><td>0.838</td></tr><tr><td>3395.307</td><td>0.654</td></tr><tr><td>81798.235</td><td>0.735</td></tr><tr><td>2386.592</td><td>0.397</td></tr><tr><td>126417.275</td><td>0.955</td></tr><tr><td>92563.84</td><td>0.851</td></tr><tr><td>68.961</td><td>0.761</td></tr><tr><td>2286.68</td><td>0.538</td></tr><tr><td>3950.484</td><td>0.563</td></tr><tr><td>3370.328</td><td>0.574</td></tr><tr><td>99247.528</td><td>0.767</td></tr><tr><td>5127.997</td><td>0.554</td></tr><tr><td>68485.374</td><td>0.665</td></tr><tr><td>110507.909</td><td>0.81</td></tr><tr><td>85127.296</td><td>0.783</td></tr><tr><td>155543.775</td><td>0.887</td></tr><tr><td>214315.785</td><td>0.9</td></tr><tr><td>76791.536</td><td>0.947</td></tr><tr><td>37383.667</td><td>0.756</td></tr><tr><td>29635.06</td><td>0.759</td></tr><tr><td>
r><tr><td>58220.244</td><td>0.743</td></tr><tr><td>121512.647</td><td>0.901</td></tr><tr><td>16478.2</td><td>0.703</td></tr><tr><td>157198.896</td><td>0.932</td></tr><tr><td>220959.336</td><td>0.812</td></tr><tr><td>2281.8</td><td>0.477</td></tr><tr><td>4020.206</td><td>0.496</td></tr><tr><td>3197.734</td><td>0.48</td></tr><tr><td>9379.326</td><td>0.592</td></tr><tr><td>95442.884</td><td>0.888</td></tr><tr><td>52293.943</td><td>0.779</td></tr><tr><td>48589.891</td><td>0.682</td></tr><tr><td>37605.408</td><td>0.634</td></tr><tr><td>157829.529</td><td>0.851</td></tr><tr><td>2230.524</td><td>0.51</td></tr><tr><td>122069.569</td><td>0.854</td></tr><tr><td>15409.366</td><td>0.718</td></tr><tr><td>24884.755</td><td>0.645</td></tr><tr><td>72303.442</td><td>0.783</td></tr><tr><td>50673.504</td><td>0.674</td></tr><tr><td>55486.952</td><td>0.949</td></tr><tr><td>145172.748</td><td>0.919</td></tr><tr><td>85555.679</td><td>0.892</td></tr><tr><td>30806.178</td><td>0.734</td></tr><tr><td>97233.407</td><td>0.729</td></tr><tr><td>13706.046</td><td>0.919</td></tr><tr><td>55890.884</td><td>0.825</td></tr><tr><td>4652.046</td><td>0.601</td></tr><tr><td>27730.896</td><td>0.697</td></tr><tr><td>7099.542</td><td>0.594</td></tr><tr><td>9815.889</td><td>0.916</td></tr><tr><td>95553.41</td><td>0.806</td></tr><tr><td>11451.267</td><td>0.613</td></tr><tr><td>101218.306</td><td>0.744</td></tr><tr><td>1125.824</td><td>0.48</td></tr><tr><td>54159.796</td><td>0.724</td></tr><tr><td>70861.872</td><td>0.759</td></tr><tr><td>26546.21</td><td>0.782</td></tr><tr><td>10114.554</td><td>0.527</td></tr><tr><td>180761.69</td><td>0.882</td></tr><tr><td>139270.055</td><td>0.866</td></tr><tr><td>25467.865</td><td>0.686</td></tr><tr><td>91574.232</td><td>0.75</td></tr><tr><td>1575.948</td><td>0.528</td></tr><tr><td>170622.862</td><td>0.74</td></tr><tr><td>30029.536</td><td>0.779</td></tr><tr><td>104847.596</td><td>0.774</td></tr><tr><td>878.847</td><td>0.434</td></tr><tr><td>78025.576</td><td>0.895</td></tr><tr><td>9586.594</td><td>0.583</td></tr><tr><td>253504.891</td><td>0.829</td> ...

# %%
from pyspark.ml.feature import VectorAssembler

# we want to output the values of chosen columns into a single column, as a vector, and we will call it features
vecAssembler = VectorAssembler(inputCols=["hdi"], outputCol="features")

# transform takes a df and changes columns, or appends columns
# combining column values into a single column
vecTrainDF = vecAssembler.transform(trainDF)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(vecTrainDF.select("total_cases_per_million", "features"))
# it looks funny, but the last element in features represents the vector
# so, it will be the value of HDI
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>total_cases_per_million</th><th>features</th></tr></thead><tbody><tr><td>3955.901</td><td>List(1, 1, List(), List(0.511))</td></tr><tr><td>1925.701</td><td>List(1, 1, List(), List(0.581))</td></tr><tr><td>249140.316</td><td>List(1, 1, List(), List(0.868))</td></tr><tr><td>74322.974</td><td>List(1, 1, List(), List(0.89))</td></tr><tr><td>117328.592</td><td>List(1, 1, List(), List(0.845))</td></tr><tr><td>42044.81</td><td>List(1, 1, List(), List(0.778))</td></tr><tr><td>134626.375</td><td>List(1, 1, List(), List(0.922))</td></tr><tr><td>58789.766</td><td>List(1, 1, List(), List(0.756))</td></tr><tr><td>1681.704</td><td>List(1, 1, List(), List(0.433))</td></tr><tr><td>164586.66</td><td>List(1, 1, List(), List(0.931))</td></tr><tr><td>759.824</td><td>List(1, 1, List(), List(0.452))</td></tr><tr><td>9491.983</td><td>List(1, 1, List(), List(0.632))</td></tr><tr><td>103146.235</td><td>List(1, 1, List(), List(0.816))</td></tr><tr><td>158991.475</td><td>List(1, 1, List(), List(0.852))</td></tr><tr><td>57591.821</td><td>List(1, 1, List(), List(0.814))</td></tr><tr><td>70913.95</td><td>List(1, 1, List(), List(0.823))</td></tr><tr><td>76537.051</td><td>List(1, 1, List(), List(0.716))</td></tr><tr><td>46302.287</td><td>List(1, 1, List(), List(0.718))</td></tr><tr><td>92333.199</td><td>List(1, 1, List(), List(0.814))</td></tr><tr><td>34654.34</td><td>List(1, 1, List(), List(0.838))</td></tr><tr><td>3395.307</td><td>List(1, 1, List(), List(0.654))</td></tr><tr><td>81798.235</td><td>List(1, 1, List(), List(0.735))</td></tr><tr><td>2386.592</td><td>List(1, 1, List(), List(0.397))</td></tr><tr><td>126417.275</td><td>List(1, 1, List(), List(0.955))</td></tr><tr><td>92563.84</td><td>List(1, 1, List(), List(0.851))</td></tr><tr><td>68.961</td><td>List(1, 1, List(), List(0.761))</td></tr><tr><td>2286.68</td><td>List(1, 1, List(), List(0.538))</td></tr><tr><td>3950.484</td><td>List(1, 1, List(), List(0.563))</td></tr><tr><td>3370.328</td><td>List(1, 1, List(), List(0.574))</td></tr><tr><td>99247.528</td><td>List(1, 1, List(), List(0.767))</td></tr><tr><td>5127.997</td><td>List(1, 1, List(), List(0.554))</td></tr><tr><td>68485.374</td><td>List(1, 1, List(), List(0.665))</td></tr><tr><td>110507.909</td><td>List(1, 1, List(), List(0.81))</td></tr><tr><td>85127.296</td><td>List(1, 1, List(), List(0.783))</td></tr><tr><td>155543.775</td><td>List(1, 1, List(), List(0.887))</td></tr><tr><td>214315.785</td><td>List(1, 1, List(), List(0.9))</td></tr><tr><td>76791.536</td><td>List(1, 1, List(), List(0.947))</td></tr><tr><td>37383.667</td><td>List(1, 1, List(), List(0.756))</td></tr><tr><td>29635.06</td><td>List(1, 1, List(), List(0.759))</td></tr><tr><td>2105.534</td><td>List(1, 1, List(), List(0.459))</td></tr><tr><td>112806.807</td><td>List(1, 1, List(), List(0.904))</td></tr><tr><td>171189.295</td><td>List(1, 1, List(), List(0.892))</td></tr><tr><td>35912.768</td><td>List(1, 1, List(), List(0.938))</td></tr><tr><td>58220.244</td><td>List(1, 1, List(), List(0.743))</td></tr><tr><td>121512.647</td><td>List(1, 1, List(), List(0.901))</td></tr><tr><td>16478.2</td><td>List(1, 1, List(), List(0.703))</td></tr><tr><td>157198.896</td><td>List(1, 1, List(), List(0.932))</td></tr><tr><td>220959.336</td><td>List(1, 1, List(), List(0.812))</td></tr><tr><td>2281.8</td><td>List(1, 1, List(), List(0.477))</td></tr><tr><td>4020.206</td><td>List(1, 1, List(), List(0.496))</td></tr><tr><td>3197.734</td><td>List(1, 1, List(), List(0.48))</td></tr><tr><td>9379.326</td><td>List(1, 1, List(), List(0.592))</td></tr><tr><td>95442.884</td><td>List(1, 1, List(), List(0.888))</td></tr><tr><td>52293.943</td><td>List(1, 1, List(), List(0.779))</td></tr><tr><td>48589.891</td><td>List(1, 1, List(), List(0.682))</td></tr><tr><td>37605.408</td><td>List(1, 1, List(), List(0.634))</td></tr><tr><td>157829.529</td><td>List(1, 1, List(), List(0.851))</td></tr><tr><td>2230.524< ...

# %%
lr = LinearRegression(featuresCol="features", labelCol="total_cases_per_million")
lrModel = lr.fit(vecTrainDF)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## Inspect the model

# %%
m = lrModel.coefficients[0]
b = lrModel.intercept

print(f"The formula for the linear regression line is y = {m:.2f}x + {b:.2f}")

# En este caso nuestra x es el valor de HDI
# si un pais tiene 0.5, esperariamos -1271.55
# si tuviera 0.9, esperariamos 111,667.68
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">The formula for the linear regression line is y = 282348.08x + -142445.59
# </div>

# %% [markdown]
# ## Apply model to test set

# %%
vecTestDF = vecAssembler.transform(testDF)

predDF = lrModel.transform(vecTestDF)

predDF.select("hdi", "features", "total_cases_per_million", "prediction").show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----+--------+-----------------------+-------------------+
#   hdi|features|total_cases_per_million|         prediction|
# +-----+--------+-----------------------+-------------------+
# 0.795| [0.795]|              70611.786|  82021.13528007633|
# 0.776| [0.776]|             115145.978|   76656.5216917992|
# 0.944| [0.944]|               8749.151| 124090.99973551271|
# 0.545| [0.545]|               1999.593|  11434.11438169307|
#  0.78|  [0.78]|              85942.247|  77785.91402617333|
# 0.765| [0.765]|             103634.293|  73550.69277227033|
# 0.929| [0.929]|              48107.208| 119855.77848160977|
#  0.48|  [0.48]|                640.932| -6918.511051886599|
# 0.524| [0.524]|              13484.375|   5504.80462622887|
# 0.742| [0.742]|              86016.738|  67056.68684961906|
#  0.94|  [0.94]|              93265.583| 122961.60740113858|
# 0.748| [0.748]|               4756.612|  68750.77535118026|
# 0.707| [0.707]|               3516.592|  57174.50392384539|
# 0.485| [0.485]|               3161.884| -5506.770633918932|
# 0.611| [0.611]|                4136.06| 30069.087898866244|
# 0.663| [0.663]|              34045.616|  44751.18824572995|
# 0.955| [0.955]|              122590.16| 127196.82865504158|
# 0.916| [0.916]|              146594.12|  116185.2533948938|
# 0.737| [0.737]|             115614.117|  65644.94643165139|
# 0.483| [0.483]|               3160.068|-6071.4668011059985|
# +-----+--------+-----------------------+-------------------+
# only showing top 20 rows
#
# </div>

# %% [markdown]
# ## Evaluate Model
#
# Let's see how our linear regression model with just one variable does. Does it beat our baseline model?

# %%
from pyspark.ml.evaluation import RegressionEvaluator

regressionEvaluator = RegressionEvaluator(predictionCol="prediction", labelCol="total_cases_per_million", metricName="rmse")

rmse = regressionEvaluator.evaluate(predDF)
print(f"RMSE is {rmse}")

r2 = regressionEvaluator.setMetricName("r2").evaluate(predDF)
print(f"r2 is {r2}")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">RMSE is 35007.88726699643
# r2 is 0.3749156266340665
# </div>

# %% [markdown]
# El error es muy alto, pero la r2 mejoro

# %% [markdown]
# -sandbox
# &copy; 2020 Databricks, Inc. All rights reserved.<br/>
# Apache, Apache Spark, Spark and the Spark logo are trademarks of the <a href="http://www.apache.org/">Apache Software Foundation</a>.<br/>
# <br/>
# <a href="https://databricks.com/privacy-policy">Privacy Policy</a> | <a href="https://databricks.com/terms-of-use">Terms of Use</a> | <a href="http://help.databricks.com/">Support</a>
